# %%
import numpy as np
import pandas as pd
from music21 import *
import pickle
from KojakLibrary import ProcessMusic as KJPM
from IPython.display import clear_output

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def remove_dupes(input_list):
    new_list = [input_list[0]]
    for item in input_list[1:]:
        if item != new_list[-1]:
            new_list.append(item)
    return new_list

# %%
with open('df_song_links_chord_melody_seq.pkl', 'rb') as pkl:
    df_song_links_chord_melody_seq = pickle.load(pkl)

# %%
melodies = df_song_links_chord_melody_seq['Melody_Data'].apply(lambda x: np.array(x)).values

# %%
melodies = [np.array(remove_dupes(melody)) for melody in melodies]

# %%
melodies[0]
# Out:
# array([10,  9,  3,  2,  8,  7,  1,  0,  7,  1,  8,  0,  7,  1,  8,  0,  7,
#         0,  7,  8,  3,  1,  7,  0,  7,  0,  7,  4, 11,  9,  4,  2,  9,  4,
#        11,  9,  4, 11,  6, 11,  6, 11,  6,  4,  9,  2,  7,  0,  7,  0,  7,
#         0,  7,  5,  0,  7,  0,  7,  2,  0,  7,  0,  5,  0, 10,  5, 10,  4,
#        11,  4,  3, 10,  2,  9,  2,  7,  2,  3,  8,  0,  7,  0,  7,  8,  3,
#         1,  7,  0,  7,  0,  7,  4, 11,  9,  4,  2,  9,  4, 11,  9,  4, 11,
#         6, 11,  6, 11,  6,  4,  9,  2,  7,  0,  7,  0,  7,  0,  7,  5,  0,
#         7,  0,  7,  2,  0,  7,  0,  5,  0, 10,  5, 10,  4, 11,  4,  3, 10,
#         2,  9,  2,  7,  2,  3,  8,  0,  7,  0,  7,  8,  3,  1,  7,  0,  7,
#         0,  7,  4, 11,  9,  4,  2,  9,  4, 11,  9,  4, 11,  6, 11,  6, 11,
#         6,  4,  9,  2,  7,  0,  7,  0,  7,  0,  7,  5,  0,  7,  0,  7,  2,
#         0,  7,  0,  5,  0, 10,  5, 10,  4, 11,  4,  3, 10,  2,  9,  2,  7,
#         2,  3,  8,  0,  7,  0,  7,  8,  3,  1,  7,  0,  7,  0,  7,  4, 11,
#         9,  4,  2,  9,  4, 11,  9,  4, 11,  6, 11,  6, 11,  6,  4,  9,  2,
#         7,  0,  7,  0,  7,  0,  7,  5,  0,  7,  0,  7,  2,  0,  7,  0,  5,
#         0, 10,  5, 10,  4, 11,  4,  3, 10,  2,  9,  2,  7,  2,  3,  8,  0,
#         7,  0,  7,  8,  3,  1,  7,  0,  7,  0,  7,  4, 11,  9,  4,  2,  9,
#         4, 11,  9,  4, 11,  6, 11,  6, 11,  6,  4,  9,  2,  7,  0,  7,  0,
#         7,  0,  7,  5,  0,  7,  0,  7,  2,  0,  7,  0,  5,  0, 10,  5, 10,
#         4, 11,  4,  3, 10,  2,  9,  2,  7,  2,  3,  8,  0,  7,  5,  0,  5,
#         0,  7,  5,  0,  5,  0,  7,  5,  0,  5,  0,  7,  5,  0,  5,  0,  7,
#         5,  0,  5,  0,  7])

# %%
# my_midi = KJPM.load_midi('bruno_mars-locked_out_of_heaven.mid')
my_midi = KJPM.load_midi('bruno_mars-locked_out_of_heaven.mid')

# %%
music_parts = [part for part in my_midi.parts]

# %%
cmap = plt.cm.get_cmap("Blues")
for part in music_parts:
    try:
        plt.figure(figsize=(20,8))
        plt.contourf(KJPM.create_grid(part), cmap=cmap)
#         plt.title(part.partName)
        plt.xlim(100,500)
        plt.ylim(20,60)
    except:
        continue

# %%
part = [p for p in music_parts if p.partName == 'Flute'][0]
part_key = part.analyze('key')
part_notes = []
for p in part.recurse():
    try:
        if p.isNote:
            part_notes.append(p)
    except:
        continue

# %%
def notes2seq(seq, inp_key, inp_mode):
    primary_key = key.Key(inp_key, inp_mode)
    primary_root = primary_key.getTonic().pitchClass
    note_seq = []
    for i, s in enumerate(seq):
        clear_output(wait=True)
        print('%d/%d' % (i+1, len(seq)))
        
        if s.isNote:
            new_note = s.pitchClass
            note_offset = new_note - primary_root
            note_offset = new_note - primary_root
            if note_offset < 0:
                note_offset = note_offset + 12
                
            if (len(note_seq) > 0) and (note_seq[-1] == note_offset):
                continue
            else:
                note_seq.append(note_offset)
    return note_seq

# %%
melody_sequence = notes2seq(part_notes, part_key.tonic, part_key.mode)
melody_sequence = np.array(melody_sequence[3:])
# Out:
# 1002/1002

# %%
plt.figure(figsize=(20,4))
# plt.scatter(x=range(len(melody_sequence[:20])), y=melody_sequence[:20])
plt.scatter(x=range(len(melody_sequence)), y=melody_sequence)

# %%
seq_sect = range(0,100)
plt.figure(figsize=(20,4))
# plt.scatter(x=range(len(melody_sequence[:20])), y=melody_sequence[:20])
plt.scatter(x=range(len(seq_sect)), y=melody_sequence[seq_sect])

# %%
target_sequence = ','.join([str(x) for x in melody_sequence[70:120].tolist()])

# %%
jazz_sequences = []
for seq in melodies:
    jazz_sequences.append(','.join([str(x) for x in seq.tolist()]))

# %%
for seq in jazz_sequences:
    if target_sequence in seq:
        print("Found")

# %%
target_sequence
# Out:
# '5,7,5,4,0,10,7,0,4,5,0,10,7,5,7,5,0,10,7,0,4,5,0,10,7,0,5,0,10,7,0,4,5,0,10,7,5,7,10,4,10,4,10,4,10,4,10,4,10,4'

# %%
# jazz_sequences

# %%
def target_distances(target_sequence, jazz_sequences):
    n = len(target_sequence)
    dist = []
    for k,jazz in enumerate(jazz_sequences):
        s=-1
        d = []
        while True:
            e=0;j=0
            for i in range(s+1,len(jazz)):
                if j>=n:
                    break
                if jazz[i]==target_sequence[j]:
                    if j==0:
                        s=i
                    elif j==n-1:
                        e=i
                    j+=1
            if e:
                d.append((e-s+1,k))
            else:
                d.append((100000,k))
                break
        dist.append(min(d))
    print(min(dist))
    return dist

# %%
dist = target_distances(target_sequence, jazz_sequences)
# Out:
# (579, 184)

# %%
sorted(dist)
# Out:
# [(579, 184),
#  (641, 232),
#  (641, 233),
#  (665, 115),
#  (665, 116),
#  (713, 1),
#  (713, 2),
#  (1021, 3),
#  (1021, 4),
#  (100000, 0),
#  (100000, 5),
#  (100000, 6),
#  (100000, 7),
#  (100000, 8),
#  (100000, 9),
#  (100000, 10),
#  (100000, 11),
#  (100000, 12),
#  (100000, 13),
#  (100000, 14),
#  (100000, 15),
#  (100000, 16),
#  (100000, 17),
#  (100000, 18),
#  (100000, 19),
#  (100000, 20),
#  (100000, 21),
#  (100000, 22),
#  (100000, 23),
#  (100000, 24),
#  (100000, 25),
#  (100000, 26),
#  (100000, 27),
#  (100000, 28),
#  (100000, 29),
#  (100000, 30),
#  (100000, 31),
#  (100000, 32),
#  (100000, 33),
#  (100000, 34),
#  (100000, 35),
#  (100000, 36),
#  (100000, 37),
#  (100000, 38),
#  (100000, 39),
#  (100000, 40),
#  (100000, 41),
#  (100000, 42),
#  (100000, 43),
#  (100000, 44),
#  (100000, 45),
#  (100000, 46),
#  (100000, 47),
#  (100000, 48),
#  (100000, 49),
#  (100000, 50),
#  (100000, 51),
#  (100000, 52),
#  (100000, 53),
#  (100000, 54),
#  (100000, 229),
#  (100000, 230),
#  (100000, 231),
#  (100000, 234),
#  (100000, 235),
#  (100000, 236),
#  (100000, 237),
#  (100000, 238),
#  (100000, 239),
#  (100000, 240),
#  (100000, 241),
#  (100000, 242),
#  (100000, 243),
#  (100000, 244),
#  (100000, 245),
#  (100000, 246),
#  (100000, 247)]

# %%
# n = len(target_sequence)
# dist = []
# for k,jazz in enumerate(jazz_sequences):
#     i=0;j=0;s=0;e=0
#     for i in range(len(jazz)):
#         if j>=n:
#             break
#         if jazz[i]==target_sequence[j]:
#             if j==0:
#                 s=i
#             elif j==n-1:
#                 e=i
#             j+=1
#     if e:
#         dist.append((e-s,k))
#     else:
#         dist.append((100000,k))
# min(dist)

# %%
target_sequence
# Out:
# '5,7,5,4,0,10,7,0,4,5,0,10,7,5,7,5,0,10,7,0,4,5,0,10,7,0,5,0,10,7,0,4,5,0,10,7,5,7,10,4,10,4,10,4,10,4,10,4,10,4'

# %%
jazz_sequences[184]
# Out:
# '5,2,3,4,5,9,10,7,8,4,5,0,3,4,5,2,0,2,4,5,6,3,4,5,6,10,11,8,9,5,6,1,4,5,6,3,1,3,5,6,5,2,3,4,5,9,10,7,8,4,5,0,3,4,5,8,10,0,5,0,3,4,5,10,8,10,5,0,3,7,5,0,3,0,5,0,3,4,5,10,8,10,5,0,3,7,5,1,4,5,6,1,4,5,6,9,11,1,6,1,4,8,6,9,11,1,5,0,3,4,5,10,8,10,5,0,3,7,5,8,10,0,5,2,3,4,5,9,10,7,8,4,5,0,3,4,5,2,0,2,4,5,2,3,4,5,9,10,7,8,4,5,0,3,4,5,2,0,2,4,5,6,3,4,5,6,10,11,8,9,5,6,1,4,5,6,3,1,3,5,6,5,2,3,4,5,9,10,7,8,4,5,0,3,4,5,8,10,0,5,7,8,10,0,1,2,1,0,8,7,6,5,2,1,0,5,7,8,10,0,1,2,4,5,3,2,1,0,10,8,0,5,3,2,1,0,2,3,4,5,7,8,10,0,2,3,2,0,8,0,5,7,8,7,6,5,3,7,5,3,2,1,0,1,0,8,10,0,5,0,3,4,5,10,8,10,5,0,3,7,5,0,3,0,5,0,3,4,5,10,8,10,5,0,3,7,5,1,4,5,6,1,4,5,6,9,11,1,6,1,4,8,6,9,11,1,5,0,3,4,5,10,8,10,5,0,3,7,5,8,10,0,5,2,3,4,5,9,10,7,8,4,5,0,3,4,5,0,3,4,5,10,8,10,5,0,3,7,5,0,3,0,5,0,3,4,5,10,8,10,5,0,3,7,5,1,4,5,6,1,4,5,6,9,11,1,6,1,4,8,6,9,11,1,5,0,3,4,5,10,8,10,5,0,3,7,5,8,10,0,5,2,3,4,5,9,10,7,8,4,5,0,3,4,5,2,3,4,5,9,10,7,8,4,5,0,3,4,5,2,0,2,4,5,2,3,4,5,9,10,7,8,4,5,0,3,4,5,2,0,2,4,5'

# %%
df_song_links_chord_melody_seq.iloc[142]['Chord_Data'][0]
# Out:
# {'Chord_Root': 'F#',
#  'Chord_Root_Num': 6,
#  'Normal_Form': [0, 3],
#  'Normal_Order': [6, 9],
#  'PitchCommonName': 'F#2-interval class 3',
#  'Pitch_Names': ['F#', 'F#', 'A'],
#  'Raw_Chord': '<music21.roman.RomanNumeral i in f# minor>',
#  'Roman_Numeral': 'i',
#  'Song_Root': 'F#',
#  'Song_Root_Mode': 'minor',
#  'Song_Root_Num': 6}

# %%
part_key
# Out:
# <music21.key.Key of g# minor>
